# %%
response.text
# Out:
# '{"latitude":37.8267,"longitude":-122.4233,"timezone":"America/Los_Angeles","currently":{"time":1559837246,"summary":"Partly Cloudy","icon":"partly-cloudy-day","nearestStormDistance":147,"nearestStormBearing":68,"precipIntensity":0,"precipProbability":0,"temperature":57.08,"apparentTemperature":57.08,"dewPoint":49.76,"humidity":0.77,"pressure":1014.85,"windSpeed":7.6,"windGust":14.6,"windBearing":269,"cloudCover":0.42,"uvIndex":3,"visibility":9.29,"ozone":321.89},"minutely":{"summary":"Partly cloudy for the hour.","icon":"partly-cloudy-day","data":[{"time":1559837220,"precipIntensity":0,"precipProbability":0},{"time":1559837280,"precipIntensity":0,"precipProbability":0},{"time":1559837340,"precipIntensity":0,"precipProbability":0},{"time":1559837400,"precipIntensity":0,"precipProbability":0},{"time":1559837460,"precipIntensity":0,"precipProbability":0},{"time":1559837520,"precipIntensity":0,"precipProbability":0},{"time":1559837580,"precipIntensity":0,"precipProbability":0},{"time":1
# ...

# %%
import requests

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/37.8267,-122.4233')
data = response.json()
data['currently']['temperature']
# Out:
# 57.08

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
data['latitude'] == 37.8367, data['longitude'] == -122.4233
# Out:
# (False, True)

# %%
data
# Out:
# {'latitude': 37.8267,
#  'longitude': -122.4233,
#  'timezone': 'America/Los_Angeles',
#  'currently': {'time': 1559836677,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'nearestStormDistance': 119,
#   'nearestStormBearing': 347,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 56.82,
#   'apparentTemperature': 56.82,
#   'dewPoint': 49.75,
#   'humidity': 0.77,
#   'pressure': 1014.82,
#   'windSpeed': 7.46,
#   'windGust': 14.28,
#   'windBearing': 269,
#   'cloudCover': 0.42,
#   'uvIndex': 3,
#   'visibility': 9.16,
#   'ozone': 321.43},
#  'minutely': {'summary': 'Partly cloudy for the hour.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1559836620, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559836680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559836740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559836800, 'precipIntensity': 0, 'precipProbability': 0},
# ...

# %%
data['currently']['temperature']
# Out:
# 56.82

# %%
response = requests.get('https://api.darksky.net/forecast/"DARKSKY_API_KEY"')
data = response.json()
data['currently']['temperature']
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-54-0c4004e5199e> in <module>()
#       1 response = requests.get('https://api.darksky.net/forecast/"DARKSKY_API_KEY"')
# ----> 2 data = response.json()
#       3 data['currently']['temperature']
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     894                     # used.
#     895                     pass
# --> 896         return complexjson.loads(self.text, **kwargs)
#     897
#     898     @property
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
# ...

# %%
# !touch.env
# Out:
# /bin/sh: touch.env: command not found

# %%
# !touch .env

# %%
# !pip install python-dotenv
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from dotenv import load_dotenv
load_dotenv()
import os

SECRET_KEY = os.getenv("DARKSKY_API_KEY")

# %%
import os
os.getenv('PATH')
# Out:
# '/Library/Frameworks/Python.framework/Versions/3.6/bin:/Library/Frameworks/Python.framework/Versions/3.6/bin:/Users/yangjing/anaconda3/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin'

# %%
# !TOUCH .super_secret_file
